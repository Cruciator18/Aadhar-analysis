# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plotting(dist_group):
    plt.figure(figsize=(12, 6))

    dist_group.plot(kind='bar', width=1, figsize=(15, 10))

    plt.title('Population Comparison: Age 5-17 vs 17+ by State', fontsize=14)
    plt.xlabel('State', fontsize=1)
    plt.ylabel('Count', fontsize=12)
    plt.xticks(rotation=85)
    plt.legend(['Age 5-17', 'Age 17+'], title='Age Group')
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

# %%
bio = pd.read_csv(r"combined_data.csv")



bio['date'] = pd.to_datetime(bio['date'], format='%d-%m-%Y')

state_group = bio.groupby('state')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(state_group)

# %%
jnk_data = bio[bio['state'] == 'Jammu & Kashmir']


jnk_dist_group = jnk_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(jnk_dist_group)

# %%
ap_data = bio[bio['state'] == 'Andhra Pradesh']


ap_dist_group = ap_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(ap_dist_group)

# %%
arunachal_data = bio[bio['state'] == 'Arunachal Pradesh']


arunachal_dist_group = arunachal_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(arunachal_dist_group)

# %%
asm_data = bio[bio['state'] == 'Assam']


asm_dist_group = asm_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(asm_dist_group)

# %%
bihar_data = bio[bio['state'] == 'Bihar']


bihar_dist_group = bihar_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(bihar_dist_group)

# %%
chhatisgarh_data = bio[bio['state'] == 'Chhattisgarh']


chhattisgarh_dist_group = chhatisgarh_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(chhattisgarh_dist_group)

# %%
goa_data = bio[bio['state'] == 'Goa']


goa_dist_group = goa_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(goa_dist_group)

# %%
gujarat_data = bio[bio['state'] == 'Gujarat']


gujarat_dist_group = gujarat_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(gujarat_dist_group)

# %%
haryana_data = bio[bio['state'] == 'Haryana']


haryana_dist_group = haryana_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(haryana_dist_group)

# %%
hp_data = bio[bio['state'] == 'Himachal Pradesh']


hp_dist_group = hp_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(hp_dist_group)

# %%
jharkhand_data = bio[bio['state'] == 'Jharkhand']


jharkhand_dist_group = jharkhand_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(jharkhand_dist_group)

# %%
karnataka_data = bio[bio['state'] == 'Karnataka']


karnataka_dist_group = karnataka_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(karnataka_dist_group)

# %%
kerala_data = bio[bio['state'] == 'Kerala']


kerala_dist_group = kerala_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(kerala_dist_group)

# %%
karnataka_data = bio[bio['state'] == 'Karnataka']


karnataka_dist_group = karnataka_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()

plotting(karnataka_dist_group)

# %%
mp_data = bio[bio['state'] == 'Madhya Pradesh']


mp_dist_group = mp_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(mp_dist_group)

# %%
maharashtra_data = bio[bio['state'] == 'Maharashtra']


maharashtra_dist_group = maharashtra_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(maharashtra_dist_group)

# %%
manipur_data = bio[bio['state'] == 'Manipur']


manipur_dist_group = manipur_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(manipur_dist_group)

# %%
nagaland_data = bio[bio['state'] == 'Nagaland']


nagaland_dist_group = nagaland_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(nagaland_dist_group)

# %%
odisha_data = bio[bio['state'] == 'Odisha']


odisha_dist_group = odisha_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(odisha_dist_group)

# %%
punjab_data = bio[bio['state'] == 'Punjab']


punjab_dist_group = punjab_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(punjab_dist_group)

# %%
rajasthan_data = bio[bio['state'] == 'Rajasthan']


rajasthan_dist_group = rajasthan_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(rajasthan_dist_group)

# %%
sikkim_data = bio[bio['state'] == 'Sikkim']


sikkim_dist_group = sikkim_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(sikkim_dist_group)

# %%
tn_data = bio[bio['state'] == 'Tamil Nadu']


tn_dist_group = tn_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(tn_dist_group)

# %%
telangana_data = bio[bio['state'] == 'Telangana']


telangana_dist_group =  telangana_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(telangana_dist_group)

# %%
tripura_data = bio[bio['state'] == 'Tripura']


tripura_dist_group = tripura_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(tripura_dist_group)

# %%
up_data = bio[bio['state'] == 'Uttar Pradesh']


up_dist_group = up_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(up_dist_group)

# %%
uk_data = bio[bio['state'] == 'Uttarakhand']


uk_dist_group = uk_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(uk_dist_group)

# %%
wb_data = bio[bio['state'] == 'West Bengal']
bio['state'] = bio['state'].str.strip().str.title()



wb_dist_group = wb_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(wb_dist_group)

# %%
ani_data = bio[bio['state'] == 'Andaman & Nicobar Islands']


ani_dist_group = ani_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(ani_dist_group)

# %%
dnd_data = bio[bio['state'] == 'Dadra and Nagar Haveli']


dnd_dist_group = dnd_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(dnd_dist_group)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[120], line 7
#       1 dnd_data = bio[bio['state'] == 'Dadra and Nagar Haveli']
#       4 dnd_dist_group = dnd_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()
# ----> 7 plotting(dnd_dist_group)
#
# Cell In[89], line 4, in plotting(dist_group)
#       1 def plotting(dist_group):
#       2     plt.figure(figsize=(12, 6))
# ----> 4     dist_group.plot(kind='bar', width=1, figsize=(15, 10))
#       6     plt.title('Population Comparison: Age 5-17 vs 17+ by State', fontsize=14)
#       7     plt.xlabel('State', fontsize=1)
#
# File c:\aadhar\.venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
daman_data = bio[bio['state'] == 'Daman and Diu']


daman_dist_group = daman_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(daman_dist_group)

# %%
delhi_data = bio[bio['state'] == 'Delhi']


delhi_dist_group = delhi_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(delhi_dist_group)

# %%
lakshadweep_data = bio[bio['state'] == 'Lakshadweep']


lakshadweep_dist_group = lakshadweep_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(lakshadweep_dist_group)

# %%
Ladakh_data = bio[bio['state'] == 'Ladakh']


Ladakh_dist_group = Ladakh_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(Ladakh_dist_group)

# %%
puducherry_data = bio[bio['state'] == 'Puducherry']


puducherry_dist_group = puducherry_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()


plotting(puducherry_dist_group)

# %%
Dadra and Nagar Haveli and Daman and Diu

# %% [markdown]
# puducherry_data = bio[bio['state'] == 'Dadra and Nagar Haveli and Daman and Diu']
#
#
# puducherry_dist_group = puducherry_data.groupby('district')[['bio_age_5_17', 'bio_age_17_']].sum()
#
#
# plotting(puducherry_dist_group)
